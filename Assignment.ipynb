# %%
import pandas as pd 
MyData = pd.read_csv("Desktop\world-happiness-report-2019.csv")

display(MyData)
# Out:
#              Country (region)  Ladder  SD of Ladder  Positive affect  \
# 0                     Finland       1             4             41.0
# 1                     Denmark       2            13             24.0
# 2                      Norway       3             8             16.0
# 3                     Iceland       4             9              3.0
# 4                 Netherlands       5             1             12.0
# ..                        ...     ...           ...              ...
# 151                    Rwanda     152            63             54.0
# 152                  Tanzania     153           122             78.0
# 153               Afghanistan     154            25            152.0
# 154  Central African Republic     155           117            132.0
# 155               South Sudan     156           140            127.0
#
#      Negative affect  Social support  Freedom  Corruption  Generosity  \
# ...

# %%
def DataCleaning(MyData):
    return(MyData)

MyData = MyData.dropna(how='any')
MyData.isnull().sum()
# Out:
# Country (region)            0
# Ladder                      0
# SD of Ladder                0
# Positive affect             0
# Negative affect             0
# Social support              0
# Freedom                     0
# Corruption                  0
# Generosity                  0
# Log of GDP\nper capita      0
# Healthy life\nexpectancy    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

#def LG():

MyData.plot(x="Ladder", y=["Social support", "Freedom", "Corruption"],
        kind="line")

plt.show()

# %%
MyData.plot(x="Ladder", y=["Social support",],
        kind="scatter")

plt.show()

# %%
MyData.plot(y=["Social support","Freedom", "Corruption"],
        kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>
